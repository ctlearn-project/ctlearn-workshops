# %%
! pwd
# Out:
# /Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/notebooks

# %%
! conda list | grep ctapipe
! conda list | grep ctlearn
! conda list | grep dl1-data-handler 
! conda list | grep tensorflow
# Out:
# ctapipe                   0.20.0                   pypi_0    pypi
# # packages in environment at /opt/anaconda3/envs/ctlearn:
# ctlearn                   0.7.0.post46              dev_0    <develop>
# dl1-data-handler          0.10.11.post35            dev_0    <develop>
# tensorflow                2.15.1                   pypi_0    pypi
# tensorflow-estimator      2.15.0                   pypi_0    pypi
# tensorflow-io-gcs-filesystem 0.37.0                   pypi_0    pypi

# %%
! du -h ../data/R1DL1_merged/*
# Out:
# 1.2G	../data/R1DL1_merged/gamma_theta_16.087_az_108.090_runs1-2.r1.dl1.h5
# 1.3G	../data/R1DL1_merged/gamma_theta_16.087_az_108.090_runs3-4.r1.dl1.h5
# 231M	../data/R1DL1_merged/proton_theta_16.087_az_108.090_runs1-3.r1.dl1.h5
# 240M	../data/R1DL1_merged/proton_theta_16.087_az_108.090_runs4-6.r1.dl1.h5

# %%
! ctlearn -h
# Out:
# usage: ctlearn [-h] [--config_file CONFIG_FILE] [--input INPUT [INPUT ...]]
#                [--pattern PATTERN [PATTERN ...]] [--mode MODE]
#                [--output OUTPUT] [--reco RECO [RECO ...]]
#                [--default_model DEFAULT_MODEL] [--clean | --no-clean]
#                [--nsb | --no-nsb] [--pretrained_weights PRETRAINED_WEIGHTS]
#                [--prediction_directory PREDICTION_DIRECTORY]
#                [--tel_types TEL_TYPES [TEL_TYPES ...]]
#                [--allowed_tels ALLOWED_TELS [ALLOWED_TELS ...]]
#                [--size_cut SIZE_CUT] [--leakage_cut LEAKAGE_CUT]
#                [--multiplicity_cut MULTIPLICITY_CUT] [--num_epochs NUM_EPOCHS]
#                [--batch_size BATCH_SIZE] [--random_seed RANDOM_SEED]
#                [--log_to_file] [--save2onnx] [--debug]
#
# Train/Predict with a CTLearn model.
#
# options:
#   -h, --help            show this help message and exit
#   --config_file CONFIG_FILE, -c CONFIG_FILE
#                         Path to YAML configuration file with training options
#   --input INPUT [INPUT ...], -i INPUT [INPUT ...]
#                         Input directories (not required when file_list is set
#                         in the config file)
#   --pattern PATTERN [PATTERN ...], -p PATTERN [PATTERN ...]
#                         Pattern to mask unwanted files from the data input
#                         directory
#   --mode MODE, -m MODE  Mode to run CTLearn; valid options: train, predict, or
#                         train_and_predict
#   --output OUTPUT, -o OUTPUT
#                         Output directory, where the logging, model weights and
#                         plots are stored
#   --reco RECO [RECO ...], -r RECO [RECO ...]
#                         Reconstruction task to perform; valid options: type,
#                         energy, direction and/or cherenkov_photons
#   --default_model DEFAULT_MODEL, -d DEFAULT_MODEL
#                         Default CTLearn Model; valid options: SingleCNN, TRN,
#                         rawwaveSingleCNN, rawwaveTRN, calwaveSingleCNN,
#                         calwaveTRN (mono), mergedTRN, and CNNRNN (stereo)
#   --clean, --no-clean   Flag, if the network should be trained with cleaned
#                         images and waveforms (default: False)
#   --nsb, --no-nsb       Flag, if the network should predict on NSB trigger
#                         patches (default: False)
#   --pretrained_weights PRETRAINED_WEIGHTS, -w PRETRAINED_WEIGHTS
#                         Path to the pretrained weights
#   --prediction_directory PREDICTION_DIRECTORY, -y PREDICTION_DIRECTORY
#                         Path to store the CTLearn predictions (optional)
#   --tel_types TEL_TYPES [TEL_TYPES ...], -t TEL_TYPES [TEL_TYPES ...]
#                         Selection of telescope types; valid option:
#                         LST_LST_LSTCam, LST_LST_LSTSiPMCam,
#                         LST_MAGIC_MAGICCam, MST_MST_FlashCam,
#                         MST_MST_NectarCam, SST_1M_DigiCam, SST_SCT_SCTCam,
#                         and/or SST_ASTRI_ASTRICam
#   --allowed_tels ALLOWED_TELS [ALLOWED_TELS ...], -a ALLOWED_TELS [ALLOWED_TELS ...]
#                         List of allowed tel_ids, others will be ignored.
#                         Selected tel_ids will be ignored, when their telescope
#                         type is not selected
#   --size_cut SIZE_CUT, -z SIZE_CUT
#                         Hillas intensity cut to perform
#   --leakage_cut LEAKAGE_CUT, -l LEAKAGE_CUT
#                         Leakage intensity cut to perform
#   --multiplicity_cut MULTIPLICITY_CUT, -u MULTIPLICITY_CUT
#                         Multiplicity cut to perform
#   --num_epochs NUM_EPOCHS, -e NUM_EPOCHS
#                         Number of epochs to train
#   --batch_size BATCH_SIZE, -b BATCH_SIZE
#                         Batch size per worker
#   --random_seed RANDOM_SEED, -s RANDOM_SEED
#                         Selection of random seed (4 digits)
#   --log_to_file         Log to a file in model directory instead of terminal
#   --save2onnx           Save model in an ONNX file
#   --debug               Print debug/logger messages

# %%
! mkdir ../my_outputs
! ctlearn --default_model TRN \
--input "../data/R1DL1_merged/" \
--pattern "*_runs1*" \
--tel_types LST_LST_LSTCam \
--reco type \
--output "../my_outputs/my_first_training_type" \
--size_cut 500
# Out:
# mkdir: ../my_outputs: File exists
# INFO:Logging has been correctly set up
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:Number of devices: 1
# INFO:Loading data:
# INFO:  For a large dataset, this may take a while...
# /Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/software/dl1-data-handler/dl1_data_handler/reader.py:1214: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   pd.DataFrame(
# /Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/software/dl1-data-handler/dl1_data_handler/reader.py:1214: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block0_items] [items->None]
#
#   pd.DataFrame(
# INFO:  Number of events loaded: 879
# INFO:Setting up model:
# INFO:  Constructing model from config.
# INFO:  Model has been correctly set up from config.
# WARNING:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# INFO:  Compiling model.
# INFO:Setting up training:
# INFO:  Validation split: 0.1
# INFO:  Number of epochs: 10
# INFO:  Size of the batches per worker: 64
# INFO:  Size of the batches: 64
# INFO:  Number of training steps per epoch: 12
# INFO:  Optimizer: Adam
# INFO:  Learning rate: 0.0001
# INFO:  Learning rate reducing patience: 5
# INFO:  Learning rate reducing factor: 0.5
# INFO:  Learning rate reducing min delta: 0.01
# INFO:  Learning rate reducing min lr: 1e-05
# INFO:  Verbosity mode: 2
# INFO:  Number of workers: 1
# INFO:  Use of multiprocessing: False
# INFO:  Apply class weights:
# INFO:    Total number: 879
# INFO:    Breakdown by 'gamma' (0) with original particle id '0': 731
# INFO:    Breakdown by 'proton' (1) with original particle id '101': 148
# INFO:    Class weights: {0: 0.6012311901504788, 1: 2.9695945945945947}
# INFO:Training and evaluating...
# 2024-05-29 13:39:33.162319: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 1/10
# 2024-05-29 13:42:06.081202: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 1: val_loss improved from inf to 0.75243, saving model to ../my_outputs/my_first_training_type/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_type/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_type/ctlearn_model/assets
# 12/12 - 162s - loss: 6.3382 - accuracy: 0.5039 - auc: 0.4798 - val_loss: 0.7524 - val_accuracy: 0.2031 - val_auc: 0.2810 - lr: 1.0000e-04 - 162s/epoch - 14s/step
# Epoch 2/10
# 2024-05-29 13:44:45.612260: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 2: val_loss improved from 0.75243 to 0.47107, saving model to ../my_outputs/my_first_training_type/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_type/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_type/ctlearn_model/assets
# 12/12 - 160s - loss: 0.8892 - accuracy: 0.4336 - auc: 0.3976 - val_loss: 0.4711 - val_accuracy: 0.9219 - val_auc: 0.9763 - lr: 1.0000e-04 - 160s/epoch - 13s/step
# Epoch 3/10
# 2024-05-29 13:47:23.521385: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 3: val_loss did not improve from 0.47107
# 12/12 - 152s - loss: 0.8190 - accuracy: 0.5208 - auc: 0.5025 - val_loss: 1.5189 - val_accuracy: 0.1406 - val_auc: 0.1826 - lr: 1.0000e-04 - 152s/epoch - 13s/step
# Epoch 4/10
# 2024-05-29 13:49:58.114394: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 4: val_loss did not improve from 0.47107
# 12/12 - 155s - loss: 0.8308 - accuracy: 0.5065 - auc: 0.5184 - val_loss: 0.5895 - val_accuracy: 0.8281 - val_auc: 0.8992 - lr: 1.0000e-04 - 155s/epoch - 13s/step
# Epoch 5/10
# 2024-05-29 13:52:33.489346: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 5: val_loss did not improve from 0.47107
# 12/12 - 155s - loss: 0.7005 - accuracy: 0.4648 - auc: 0.4487 - val_loss: 0.7098 - val_accuracy: 0.3438 - val_auc: 0.3611 - lr: 1.0000e-04 - 155s/epoch - 13s/step
# Epoch 6/10
# 2024-05-29 13:55:10.997859: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 6: val_loss did not improve from 0.47107
# 12/12 - 157s - loss: 0.7316 - accuracy: 0.5938 - auc: 0.6211 - val_loss: 0.7264 - val_accuracy: 0.2969 - val_auc: 0.3290 - lr: 1.0000e-04 - 157s/epoch - 13s/step
# Epoch 7/10
# 2024-05-29 13:57:49.778572: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 7: val_loss improved from 0.47107 to 0.45091, saving model to ../my_outputs/my_first_training_type/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_type/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_type/ctlearn_model/assets
# 12/12 - 164s - loss: 0.7293 - accuracy: 0.3828 - auc: 0.3854 - val_loss: 0.4509 - val_accuracy: 0.8438 - val_auc: 0.9058 - lr: 1.0000e-04 - 164s/epoch - 14s/step
# Epoch 8/10
# 2024-05-29 14:00:43.106373: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 8: val_loss did not improve from 0.45091
# 12/12 - 168s - loss: 0.8188 - accuracy: 0.6172 - auc: 0.6623 - val_loss: 0.4914 - val_accuracy: 0.8750 - val_auc: 0.9001 - lr: 1.0000e-04 - 168s/epoch - 14s/step
# Epoch 9/10
# 2024-05-29 14:03:33.519094: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 9: val_loss did not improve from 0.45091
# 12/12 - 171s - loss: 0.8203 - accuracy: 0.5000 - auc: 0.4440 - val_loss: 1.3770 - val_accuracy: 0.1719 - val_auc: 0.2280 - lr: 1.0000e-04 - 171s/epoch - 14s/step
# Epoch 10/10
# 2024-05-29 14:06:28.892519: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 10: val_loss did not improve from 0.45091
# 12/12 - 174s - loss: 0.7805 - accuracy: 0.4518 - auc: 0.4624 - val_loss: 0.5094 - val_accuracy: 0.9062 - val_auc: 0.9353 - lr: 1.0000e-04 - 174s/epoch - 15s/step
# INFO:Training and evaluating finished succesfully!
# INFO:Plotting training history: accuracy
# INFO:Plotting training history: auc
# INFO:Plotting training history: loss
# Closing remaining open files:/Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/data/R1DL1_merged/proton_theta_16.087_az_108.090_runs1-3.r1.dl1.h5...done/Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/data/R1DL1_merged/gamma_theta_16.087_az_108.090_runs1-2.r1.dl1.h5...done

# %%
! mkdir ../my_outputs
! ctlearn --default_model TRN \
--input "../data/R1DL1_merged/" \
--pattern "gamma*_runs1*" \
--tel_types LST_LST_LSTCam \
--reco energy \
--output "../my_outputs/my_first_training_energy" \
--size_cut 500
# Out:
# mkdir: ../my_outputs: File exists
# INFO:Logging has been correctly set up
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:Number of devices: 1
# INFO:Loading data:
# INFO:  For a large dataset, this may take a while...
# /Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/software/dl1-data-handler/dl1_data_handler/reader.py:1215: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   pd.DataFrame(
# /Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/software/dl1-data-handler/dl1_data_handler/reader.py:1215: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block0_items] [items->None]
#
#   pd.DataFrame(
# INFO:  Number of events loaded: 731
# INFO:Setting up model:
# INFO:  Constructing model from config.
# INFO:  Model has been correctly set up from config.
# WARNING:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# INFO:  Compiling model.
# INFO:Setting up training:
# INFO:  Validation split: 0.1
# INFO:  Number of epochs: 10
# INFO:  Size of the batches per worker: 64
# INFO:  Size of the batches: 64
# INFO:  Number of training steps per epoch: 10
# INFO:  Optimizer: Adam
# INFO:  Learning rate: 0.0001
# INFO:  Learning rate reducing patience: 5
# INFO:  Learning rate reducing factor: 0.5
# INFO:  Learning rate reducing min delta: 0.01
# INFO:  Learning rate reducing min lr: 1e-05
# INFO:  Verbosity mode: 2
# INFO:  Number of workers: 1
# INFO:  Use of multiprocessing: False
# INFO:Training and evaluating...
# 2024-05-29 14:06:40.686046: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 1/10
# 2024-05-29 14:08:54.686378: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 1: val_loss improved from inf to 1.77016, saving model to ../my_outputs/my_first_training_energy/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# 10/10 - 144s - loss: 4.0765 - mae_energy: 4.0765 - val_loss: 1.7702 - val_mae_energy: 1.7702 - lr: 1.0000e-04 - 144s/epoch - 14s/step
# Epoch 2/10
# 2024-05-29 14:11:24.541881: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 2: val_loss improved from 1.77016 to 0.72180, saving model to ../my_outputs/my_first_training_energy/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# 10/10 - 149s - loss: 1.0364 - mae_energy: 1.0364 - val_loss: 0.7218 - val_mae_energy: 0.7218 - lr: 1.0000e-04 - 149s/epoch - 15s/step
# Epoch 3/10
# 2024-05-29 14:13:45.392524: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 3: val_loss improved from 0.72180 to 0.45072, saving model to ../my_outputs/my_first_training_energy/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# 10/10 - 141s - loss: 0.7707 - mae_energy: 0.7707 - val_loss: 0.4507 - val_mae_energy: 0.4507 - lr: 1.0000e-04 - 141s/epoch - 14s/step
# Epoch 4/10
# 2024-05-29 14:16:14.573023: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 4: val_loss did not improve from 0.45072
# 10/10 - 143s - loss: 0.5559 - mae_energy: 0.5559 - val_loss: 0.4548 - val_mae_energy: 0.4548 - lr: 1.0000e-04 - 143s/epoch - 14s/step
# Epoch 5/10
# 2024-05-29 14:18:25.813850: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 5: val_loss improved from 0.45072 to 0.44724, saving model to ../my_outputs/my_first_training_energy/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# 10/10 - 136s - loss: 0.4731 - mae_energy: 0.4731 - val_loss: 0.4472 - val_mae_energy: 0.4472 - lr: 1.0000e-04 - 136s/epoch - 14s/step
# Epoch 6/10
# 2024-05-29 14:29:49.973338: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 6: val_loss did not improve from 0.44724
# 10/10 - 678s - loss: 0.4527 - mae_energy: 0.4527 - val_loss: 0.5047 - val_mae_energy: 0.5047 - lr: 1.0000e-04 - 678s/epoch - 68s/step
# Epoch 7/10
# 2024-05-29 14:31:54.763930: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 7: val_loss improved from 0.44724 to 0.41019, saving model to ../my_outputs/my_first_training_energy/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# 10/10 - 130s - loss: 0.4707 - mae_energy: 0.4707 - val_loss: 0.4102 - val_mae_energy: 0.4102 - lr: 1.0000e-04 - 130s/epoch - 13s/step
# Epoch 8/10
# 2024-05-29 14:34:03.530834: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 8: val_loss did not improve from 0.41019
# 10/10 - 123s - loss: 0.4324 - mae_energy: 0.4324 - val_loss: 0.4410 - val_mae_energy: 0.4410 - lr: 1.0000e-04 - 123s/epoch - 12s/step
# Epoch 9/10
# 2024-05-29 14:36:09.890571: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 9: val_loss improved from 0.41019 to 0.38582, saving model to ../my_outputs/my_first_training_energy/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_energy/ctlearn_model/assets
# 10/10 - 132s - loss: 0.4295 - mae_energy: 0.4295 - val_loss: 0.3858 - val_mae_energy: 0.3858 - lr: 1.0000e-04 - 132s/epoch - 13s/step
# Epoch 10/10
# 2024-05-29 14:38:28.192463: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 10: val_loss did not improve from 0.38582
# 10/10 - 133s - loss: 0.4009 - mae_energy: 0.4009 - val_loss: 0.4220 - val_mae_energy: 0.4220 - lr: 1.0000e-04 - 133s/epoch - 13s/step
# INFO:Training and evaluating finished succesfully!
# INFO:Plotting training history: loss
# INFO:Plotting training history: mae_energy
# Closing remaining open files:/Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/data/R1DL1_merged/gamma_theta_16.087_az_108.090_runs1-2.r1.dl1.h5...done/Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/data/R1DL1_merged/gamma_theta_16.087_az_108.090_runs1-2.r1.dl1.h5...done

# %%
! mkdir ../my_outputs
! ctlearn --default_model TRN \
--input "../data/R1DL1_merged/" \
--pattern "gamma*_runs1*" \
--tel_types LST_LST_LSTCam \
--reco direction \
--output "../my_outputs/my_first_training_direction" \
--size_cut 500
# Out:
# mkdir: ../my_outputs: File exists
# INFO:Logging has been correctly set up
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:Number of devices: 1
# INFO:Loading data:
# INFO:  For a large dataset, this may take a while...
# /Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/software/dl1-data-handler/dl1_data_handler/reader.py:1215: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->axis0] [items->None]
#
#   pd.DataFrame(
# /Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/software/dl1-data-handler/dl1_data_handler/reader.py:1215: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block0_items] [items->None]
#
#   pd.DataFrame(
# INFO:  Number of events loaded: 731
# INFO:Setting up model:
# INFO:  Constructing model from config.
# INFO:  Model has been correctly set up from config.
# WARNING:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# INFO:  Compiling model.
# INFO:Setting up training:
# INFO:  Validation split: 0.1
# INFO:  Number of epochs: 10
# INFO:  Size of the batches per worker: 64
# INFO:  Size of the batches: 64
# INFO:  Number of training steps per epoch: 10
# INFO:  Optimizer: Adam
# INFO:  Learning rate: 0.0001
# INFO:  Learning rate reducing patience: 5
# INFO:  Learning rate reducing factor: 0.5
# INFO:  Learning rate reducing min delta: 0.01
# INFO:  Learning rate reducing min lr: 1e-05
# INFO:  Verbosity mode: 2
# INFO:  Number of workers: 1
# INFO:  Use of multiprocessing: False
# INFO:Training and evaluating...
# 2024-05-29 14:38:39.870452: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 1/10
# 2024-05-29 14:40:52.003507: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 1: val_loss improved from inf to 3.84367, saving model to ../my_outputs/my_first_training_direction/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_direction/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_direction/ctlearn_model/assets
# 10/10 - 142s - loss: 6.6475 - mae_direction: 6.6475 - val_loss: 3.8437 - val_mae_direction: 3.8437 - lr: 1.0000e-04 - 142s/epoch - 14s/step
# Epoch 2/10
# 2024-05-29 14:43:05.948132: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 2: val_loss improved from 3.84367 to 1.21809, saving model to ../my_outputs/my_first_training_direction/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_direction/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_direction/ctlearn_model/assets
# 10/10 - 134s - loss: 1.9792 - mae_direction: 1.9792 - val_loss: 1.2181 - val_mae_direction: 1.2181 - lr: 1.0000e-04 - 134s/epoch - 13s/step
# Epoch 3/10
# 2024-05-29 14:45:17.293314: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 3: val_loss improved from 1.21809 to 0.55191, saving model to ../my_outputs/my_first_training_direction/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_direction/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_direction/ctlearn_model/assets
# 10/10 - 132s - loss: 0.9813 - mae_direction: 0.9813 - val_loss: 0.5519 - val_mae_direction: 0.5519 - lr: 1.0000e-04 - 132s/epoch - 13s/step
# Epoch 4/10
# 2024-05-29 14:47:31.552390: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 4: val_loss improved from 0.55191 to 0.07623, saving model to ../my_outputs/my_first_training_direction/ctlearn_model/
# INFO:tensorflow:Assets written to: ../my_outputs/my_first_training_direction/ctlearn_model/assets
# INFO:Assets written to: ../my_outputs/my_first_training_direction/ctlearn_model/assets
# 10/10 - 134s - loss: 0.5982 - mae_direction: 0.5982 - val_loss: 0.0762 - val_mae_direction: 0.0762 - lr: 1.0000e-04 - 134s/epoch - 13s/step
# Epoch 5/10
# 2024-05-29 14:49:43.775579: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 5: val_loss did not improve from 0.07623
# 10/10 - 126s - loss: 0.2543 - mae_direction: 0.2543 - val_loss: 0.1262 - val_mae_direction: 0.1262 - lr: 1.0000e-04 - 126s/epoch - 13s/step
# Epoch 6/10
# 2024-05-29 14:51:50.849594: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 6: val_loss did not improve from 0.07623
# 10/10 - 127s - loss: 0.1960 - mae_direction: 0.1960 - val_loss: 0.1135 - val_mae_direction: 0.1135 - lr: 1.0000e-04 - 127s/epoch - 13s/step
# Epoch 7/10
# 2024-05-29 14:53:57.521522: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 7: val_loss did not improve from 0.07623
# 10/10 - 127s - loss: 0.3545 - mae_direction: 0.3545 - val_loss: 0.4928 - val_mae_direction: 0.4928 - lr: 1.0000e-04 - 127s/epoch - 13s/step
# Epoch 8/10
# 2024-05-29 14:56:05.367000: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 8: val_loss did not improve from 0.07623
# 10/10 - 128s - loss: 0.3281 - mae_direction: 0.3281 - val_loss: 0.1434 - val_mae_direction: 0.1434 - lr: 1.0000e-04 - 128s/epoch - 13s/step
# Epoch 9/10
# 2024-05-29 14:58:37.129954: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 9: val_loss did not improve from 0.07623
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 10/10 - 152s - loss: 0.2723 - mae_direction: 0.2723 - val_loss: 0.3055 - val_mae_direction: 0.3055 - lr: 1.0000e-04 - 152s/epoch - 15s/step
# Epoch 10/10
# 2024-05-29 15:00:47.121471: W tensorflow/core/framework/dataset.cc:959] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#
# Epoch 10: val_loss did not improve from 0.07623
# 10/10 - 130s - loss: 0.2356 - mae_direction: 0.2356 - val_loss: 0.2915 - val_mae_direction: 0.2915 - lr: 5.0000e-05 - 130s/epoch - 13s/step
# INFO:Training and evaluating finished succesfully!
# INFO:Plotting training history: loss
# INFO:Plotting training history: mae_direction
# Closing remaining open files:/Users/tjarkmiener/Desktop/ctlearn_workshop/ctlearn_workshop2024/data/R1DL1_merged/gamma_theta_16.087_az_108.090_runs1-2.r1.dl1.h5...done
